# %% [markdown]
# Database source:
# - [Kaggle](https://www.kaggle.com/hernan4444/anime-recommendation-database-2020)
# - [GitHub](https://github.com/Hernan4444/MyAnimeList-Database)
# - [File details](https://github.com/Hernan4444/MyAnimelist-Database/tree/master/data)

# %% [markdown]
# # Setup and Preprocessing

# %%
from loguru import logger
import nltk
from nltk.corpus import stopwords
import pickle
import re
import requests
import numpy as np
import pandas as pd
import swifter
from bs4 import BeautifulSoup
from sklearn.metrics.pairwise import cosine_similarity, sigmoid_kernel
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pd.set_option("display.max_columns", 999)
# pd.reset_option("display.max_columns")

# %%
HTML_PATH = 'T:/New Download Folder/anime_html'
DATA_DIR = 'data/'

# %%
anime_df = pd.read_csv(DATA_DIR + 'anime.csv')
print(anime_df.shape)
anime_df.head()
# Out:
# (17562, 35)
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# 2                             トライガン     TV       26
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV       26
# 4                            冒険王ビィト     TV       52
#
#                           Aired    Premiered  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1                   Sep 1, 2001      Unknown
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998
# 3   Jul 2, 2002 to Dec 24, 2002  Summer 2002
# 4  Sep 30, 2004 to Sep 29, 2005    Fall 2004
#
#                                            Producers  \
# 0                                      Bandai Visual
# 1                             Sunrise, Bandai Visual
# 2                               Victor Entertainment
# 3  TV Tokyo, Bandai Visual, Dentsu, Victor Entert...
# 4                                   TV Tokyo, Dentsu
#
#                               Licensors         Studios    Source  \
# 0      Funimation, Bandai Entertainment         Sunrise  Original
# 1           Sony Pictures Entertainment           Bones  Original
# 2  Funimation, Geneon Entertainment USA        Madhouse     Manga
# 3      Funimation, Bandai Entertainment         Sunrise  Original
# 4                               Unknown  Toei Animation     Manga
#
#           Duration                          Rating  Ranked  Popularity  \
# 0  24 min. per ep.  R - 17+ (violence & profanity)    28.0          39
# 1    1 hr. 55 min.  R - 17+ (violence & profanity)   159.0         518
# 2  24 min. per ep.       PG-13 - Teens 13 or older   266.0         201
# 3  25 min. per ep.       PG-13 - Teens 13 or older  2481.0        1467
# 4  23 min. per ep.                   PG - Children  3710.0        4369
#
#    Members  Favorites  Watching  Completed  On-Hold  Dropped  Plan to Watch  \
# 0  1251960      61971    105808     718161    71513    26678         329800
# 1   273145       1174      4143     208333     1935      770          57964
# 2   558913      12944     29113     343492    25465    13925         146918
# 3    94683        587      4300      46165     5121     5378          33719
# 4    13224         18       642       7314      766     1108           3394
#
#    Score-10   Score-9   Score-8  Score-7  Score-6 Score-5 Score-4 Score-3  \
# 0  229170.0  182126.0  131625.0  62330.0  20688.0  8904.0  3184.0  1357.0
# 1   30043.0   49201.0   49505.0  22632.0   5805.0  1877.0   577.0   221.0
# 2   50229.0   75651.0   86142.0  49432.0  15376.0  5838.0  1965.0   664.0
# 3    2182.0    4806.0   10128.0  11618.0   5709.0  2920.0  1083.0   353.0
# 4     312.0     529.0    1242.0   1713.0   1068.0   634.0   265.0    83.0
#
#   Score-2 Score-1
# 0   741.0  1580.0
# 1   109.0   379.0
# 2   316.0   533.0
# 3   164.0   131.0
# 4    50.0    27.0

# %%
anime_df.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#        'Type', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
#        'Studios', 'Source', 'Duration', 'Rating', 'Ranked', 'Popularity',
#        'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped',
#        'Plan to Watch', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
#        'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1'],
#       dtype='object')

# %%
# anime_df.rename(columns={'Genders': 'Genres'}, inplace=True)
# anime_df.to_csv(DATA_DIR + 'anime.csv', index=False)

# %%
synopsis_df = pd.read_csv(DATA_DIR + 'anime_with_synopsis.csv')
synopsis_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0     Action, Adventure, Comedy, Drama, SciFi, Space
# 1               Action, Drama, Mystery, SciFi, Space
# 2   Action, SciFi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                             synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...
#
#                                             combined
# 0  Action, Adventure, Comedy, Drama, SciFi, Space...
# 1  Action, Drama, Mystery, SciFi, Space other day...
# 2  Action, SciFi, Adventure, Comedy, Drama, Shoun...
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4  Adventure, Fantasy, Shounen, Supernatural It i...

# %%
# synopsis_df.rename(columns={'Genders': 'Genres', 'sypnopsis': 'synopsis'}, inplace=True)
# synopsis_df.to_csv(DATA_DIR + 'anime_with_synopsis.csv', index=False)

# %%
synopsis_df[synopsis_df.isna().any(axis=1)]
# Out:
#        MAL_ID                                               Name    Score  \
# 11451   34755  Kuma no Gakkou: Patissier Jackie to Ohisama no...  Unknown
# 11469   34794                                Yukai na Animal Bus  Unknown
# 13686   38475                                   Yuru Camp△ Movie  Unknown
# 15025   40714  Youkai Watch Jam: Youkai Gakuen Y - N to no So...     6.28
# 15747   42717                   Kaeru no Pickles: Kimochi no Iro  Unknown
# 16056   44848                                        Iii Icecrin  Unknown
# 16110   45731                   Argonavis from BanG Dream! Movie  Unknown
# 16120   46095                          Vivy: Fluorite Eye's Song  Unknown
#
#                                            Genres synopsis
# 11451                                Comedy, Kids      NaN
# 11469                                Comedy, Kids      NaN
# 13686                       Comedy, Slice of Life      NaN
# 15025  Comedy, Demons, Kids, Supernatural, School      NaN
# 15747                         Slice of Life, Kids      NaN
# 16056                                        Kids      NaN
# 16110                                       Music      NaN
# 16120                                      Sci-Fi      NaN

# %%
synopsis_df.dropna(inplace=True)

# %%
def clean_genres(genres):
    return genres.replace(',', '')

synopsis_df.Genres.apply(clean_genres)
# Out:
# 0               Action Adventure Comedy Drama Sci-Fi Space
# 1                        Action Drama Mystery Sci-Fi Space
# 2             Action Sci-Fi Adventure Comedy Drama Shounen
# 3           Action Mystery Police Supernatural Drama Magic
# 4                   Adventure Fantasy Shounen Supernatural
#                                ...
# 16209                       Adventure Mystery Supernatural
# 16210                           Comedy Horror Supernatural
# 16211    Mystery Dementia Horror Psychological Supernat...
# 16212                       Adventure Slice of Life Comedy
# 16213                                       Action Fantasy
# Name: Genres, Length: 16206, dtype: object

# %%
synopsis_df.Genres = synopsis_df.Genres.str.replace('Sci-Fi', 'SciFi')

# %%
synopsis_df['combined'] = synopsis_df['Genres'] + ' ' + synopsis_df['synopsis']

# %%
synopsis_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0     Action, Adventure, Comedy, Drama, SciFi, Space
# 1               Action, Drama, Mystery, SciFi, Space
# 2   Action, SciFi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                             synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...
#
#                                             combined
# 0  Action, Adventure, Comedy, Drama, SciFi, Space...
# 1  Action, Drama, Mystery, SciFi, Space other day...
# 2  Action, SciFi, Adventure, Comedy, Drama, Shoun...
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4  Adventure, Fantasy, Shounen, Supernatural It i...

# %%
# synopsis_df.to_csv(DATA_DIR + 'anime_with_synopsis.csv', index=False)

# %%
synopsis_df['combined'][0]
# Out:
# 'Action, Adventure, Comedy, Drama, SciFi, Space In the year 2071, humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet Earth behind. The Inter Solar System Police attempts to keep peace in the galaxy, aided in part by outlaw bounty hunters, referred to as "Cowboys." The ragtag team aboard the spaceship Bebop are two such individuals. Mellow and carefree Spike Spiegel is balanced by his boisterous, pragmatic partner Jet Black as the pair makes a living chasing bounties and collecting rewards. Thrown off course by the addition of new members that they meet in their travels—Ein, a genetically engineered, highly intelligent Welsh Corgi; femme fatale Faye Valentine, an enigmatic trickster with memory loss; and the strange computer whiz kid Edward Wong—the crew embarks on thrilling adventures that unravel each member\'s dark and mysterious past little by little. Well-balanced with high density action and light-hearted comedy, Cowboy Bebop is a space Western classic and an homage to the smooth and improvised music it is named after.'

# %%
synopsis_df = pd.read_csv(DATA_DIR + 'anime_with_synopsis.csv')
synopsis_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0     Action, Adventure, Comedy, Drama, SciFi, Space
# 1               Action, Drama, Mystery, SciFi, Space
# 2   Action, SciFi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                             synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...
#
#                                             combined
# 0  Action, Adventure, Comedy, Drama, SciFi, Space...
# 1  Action, Drama, Mystery, SciFi, Space other day...
# 2  Action, SciFi, Adventure, Comedy, Drama, Shoun...
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4  Adventure, Fantasy, Shounen, Supernatural It i...

# %%
def get_anime_rows(df, anime_name):
    return df[df.Name.str.contains(anime_name, case=False, regex=False)]

# %%
specific_animes = get_anime_rows(synopsis_df, 'bleach')
specific_animes
# Out:
#        MAL_ID                                               Name    Score  \
# 237       269                                             Bleach      7.8
# 679       762                       Bleach: Memories in the Rain     7.15
# 731       834                    Bleach: The Sealed Sword Frenzy     6.98
# 1468     1686                 Bleach Movie 1: Memories of Nobody     7.45
# 2431     2889  Bleach Movie 2: The DiamondDust Rebellion - Mo...     7.45
# 3342     4835  Bleach Movie 3: Fade to Black - Kimi no Na wo ...     7.52
# 4599     8247                         Bleach Movie 4: Jigoku-hen     7.61
# 11677   35118   Bleach KaraBuri!: Gotei Juusan Yatai Daisakusen!     6.51
# 13891   38810                             Bleach: Gotei 13 Omake     6.45
# 15348   41467                          Bleach: Sennen Kessen-hen  Unknown
#
#                                                   Genres  \
# 237    Action, Adventure, Comedy, Super Power, Supern...
# 679      Action, Adventure, Supernatural, Drama, Shounen
# 731    Action, Adventure, Comedy, Super Power, Supern...
# 1468   Action, Adventure, Comedy, Super Power, Supern...
# 2431   Action, Adventure, Comedy, Super Power, Supern...
# 3342   Action, Adventure, Comedy, Super Power, Supern...
# 4599   Action, Adventure, Comedy, Super Power, Supern...
# 11677                                    Comedy, Shounen
# 13891                                  Action, Adventure
# 15348  Action, Adventure, Comedy, Super Power, Supern...
#
#                                                 synopsis  \
# 237    Ichigo Kurosaki is an ordinary high schooler—u...
# 679    Kurosaki Ichigo, the temporary Shinigami(Death...
# 731    Shinigami named Baishin who was sealed by Soul...
# 1468   hen a life ends, its soul departs to its final...
# 2431   ssigned to protect a royal procession transpor...
# 3342   fter a mysterious pair attack Rukia Kuchiki an...
# 4599   "Hell" is the place where a person is sent to ...
# 11677  animated adaptation of several chapters of Col...
# 13891  No synopsis information has been added to this...
# 15348  No synopsis information has been added to this...
#
#                                                 combined  \
# 237    Action, Adventure, Comedy, Super Power, Supern...
# 679    Action, Adventure, Supernatural, Drama, Shoune...
# 731    Action, Adventure, Comedy, Super Power, Supern...
# 1468   Action, Adventure, Comedy, Super Power, Supern...
# 2431   Action, Adventure, Comedy, Super Power, Supern...
# 3342   Action, Adventure, Comedy, Super Power, Supern...
# 4599   Action, Adventure, Comedy, Super Power, Supern...
# 11677  Comedy, Shounen KurosakiIchigo, KuchikiRukia, ...
# 13891                                                NaN
# 15348                                                NaN
#
#                                               Characters
# 237            KurosakiIchigo, KuchikiRukia, AbaraiRenji
# 679           KurosakiIchigo, KuchikiRukia, InoueOrihime
# 731                KurosakiIchigo, KuchikiRukia, Baishin
# 1468                 KurosakiIchigo, KuchikiRukia, Senna
# 2431   KurosakiIchigo, HitsugayaToushirou, MatsumotoR...
# 3342               KurosakiIchigo, KuchikiRukia, Shizuku
# 4599           KurosakiIchigo, KuchikiRukia, AbaraiRenji
# 11677   KurosakiIchigo, KuchikiRukia, HitsugayaToushirou
# 13891                                                NaN
# 15348                                                NaN

# %%
try:
    print(unique_char_names)
except:
    unique_char_names = set()
# Out:
# {'nemuru', 'arrester', 'pugi', 'melchiott', 'leobort', 'baka', 'toujin', 'toucan', 'riela', 'amatsu', 'shoukichi', 'takashiro', 'tarobei', 'armin', 'pour', 'rudolf', 'gotes', 'touno', 'haru', 'retsu', 'dad', 'ichimaru', 'exkaiser', 'suomi', 'fang long', 'tatewaki', 'otone', 'exon', 'shiogami', 'fumi', 'tama-chan', 'itaru', 'the spirit of the world tree', 'tiantian', 'amao', 'ogawa', 'shirahane', 'ame', 'hong', 'shinran', 'apulo', 'jacky', 'iroha', 'mabuchi', 'asagaya', 'aisha', 'toudou', 'eurasian eagle-owl', 'irvine', 'ikue', 'dokin-chan', 'morokuzu', 'takae', 'nagaya', 'shishigami', 'bei', 'yingxiong', 'diablo', 'slaine', 'nima', 'tamiko', 'vergil', 'takagi', 'meshiya', 'hasami', 'oto', 'omega', 'agahari', 'gremory', 'noel marres', 'klaus', 'satoya', 'pe teacher', 'general', 'senkawa', 'shuichi', 'tenma white', 'tamaki', 'sakurazuki', 'huntley', 'hassan', 'moritomo', 'law', 'menmen', 'yamamoto', 'buddha', 'koda', 'hiraga', 'halkara', 'oliver', 'kasamatsu', 'yumiya', 'kokage', 'j. c. ashenbert', 'rumia', 'doctor m', 'ten', 'oland', 'kento', 'sieg', 'hakugen', 'broadron', 'marlene', 'miyabe', 'satoshi', 'cutie', 'yasuna', 'midoh', 'munechika', 'parfait', 'suzui', 'feb', 'masa', 'jinzaburou', 'escanor', 'manaduru', 'monpy', 'rosso', 'student council president', 'la arwall', 'cotton', 'voldigoad', 'tamacoron', 'hazakura', 'ryouhei', 'matsuno', 'noriaki', 'kaiho', 'ryudo', 'onsen', 'nishijou', 'himenokouji', 'gunzou', "rintarou's father", 'yatogame', 'morinome', 'rouha', 'mr. petiwell', 'tapion', 'ryougi', 'carrot', 'nightray', 'yachiyo', 'masters', 'mizugaki', 'all for one', 'fon fabre', 'zhuge', 'shokichi', 'nabeshin', 'rushuna', 'prinesca', 'jelly bean', 'kawakabe', 'nathalie', 'teru', 'junkers', 'koto', 'fina', 'libertà', 'feilong', 'rondo', 'eve', 'totoro', 'amemiya', 'willman', 'leona', 'wakabayashi', 'clackey', 'chico', 'apo', 'tantan', 'momochi', 'mar', 'kukurukku', 'soldat j', 'onna no ko', 'chokkaku', 'suefumi', 'banji', 'james ray', 'umenomori', 'akira agarkar', 'empress kin', 'king koopa', 'lyle', 'momoko', 'katta-kun', 'nozuki', 'earth', 'juli', 'reinhard', 'hard-boiled', 'noramimi', 'suzumoto', 'kouno', 'souichiro', 'suishou', 'bridegroom', 'skuld', 'melissa', 'helmut j.', 'esumi', 'monga', 'slade', 'yurino', 'kurosawa', 'shiela', 'kimichika', 'yoshii', 'tsukisaka', 'sakurajima', 'edna', 'kinoa', 'ishikawa', 'constance', 'miako', 'bolt', 'kido', 'ned', 'kreuz', 'utau', 'fioretti', 'hanon', 'uther', 'aigasaki', 'victor', 'tambour', 'grill', 'shell', 'dilah', 'kasuga', 'mock turtle', 'miroku', 'mookie', 'yukinari', 'ain', 'princess budu', 'kanda', 'eriri spencer', 'banjou', 'rosebank', 'polo', 'kamoi', 'yakovleva', 'annapuma', 'mrs. yokokawa', 'lanster', 'ittoki', 'nishiki', 'mista', 'xiaofei', 'jetter', 'anlock', 'amada', 'ro', 'tianlan', 'tenkuubashi', 'senbei', 'future trunks', 'doggy', 'r. ichirou', 'sorao', 'steak', 'ibaraki douji', 'moemi', 'tianshi', 'toono', 'hendric', 'karin', 'lando', 'souryuuin', 'hibarigaoka', 'ryuutarou', 'arikawa', 'shishidou', 'hakufu', 'oshiri kajiri mushi xviii', 'touzoku arthur', 'spoor', 'hanazawa', 'steiger', 'halifa', 'sala', 'kurai', 'nakoruru', 'hildegard', 'mika-chan', 'chanko', 'tiffa', 'kiro', 'ayaka', 'sarayashiki', 'tateyama', 'mihashi', 'postino', 'hai', 'urabe', 'kogami', 'kuriyama', 'touguu', 'nonononn', 'vertone', 'gregorio', 'antoinette', 'sven', 'gogeta', 'nabi', 'hellscythe', 'pochacco', 'euler', 'kouichi', 'homura', 'haji', 'sanders jr.', 'yukinoshita', 'yagiyama', 'plisetsky', 'bouquet', 'higashijuujou', 'éponine', 'kiyomizu', 'namba', 'maki', 'hearts 18th', 'kishinami', 'ichino', 'daga', 'asuno', 'laurant', 'ikuya', 'retsuya', 'haro', 'gauche', 'suzume', 'nyanko', 'kiyomasa', 'ritsuka', 'imei', 'rikudou', 'tokiwa', 'usa', 'soldier godal', 'rumina', 'toshiaki', 'toshihisa', "rocky's father", 'archid', 'iwata', 'chise', 'shinsuke', 'nishimikado', 'otto', 'alfonso', 'retoree', 'green', 'yoshi', 'yukimura', 'patrasche', 'tool', 'maquia', 'isaac', 'lanchester', 'lunlun ...

# %%
def get_char_names(mal_id, top_k=5):
    # mal_id = get_anime_rows(synopsis_df, anime_name).iloc[0, 0]
    # r = requests.get(f'https://myanimelist.net/anime/{mal_id}')
    # same with requesting from URL but faster
    html_path = f'{HTML_PATH}/{mal_id}/details.html'
    with open(html_path, 'r', encoding='utf-8') as f:
        html = f.read()
    soup = BeautifulSoup(html)
    chars = soup.findAll('h3', attrs={'class': 'h3_characters_voice_actors'})
    # get only top character names to remove them from synopsis
    chars = [x.a.text.strip() for x in chars[:top_k]]
    # print(chars)
    if not chars:
        return np.nan
    # regex = '|'.join(chars).replace(', ', '|')
    # make joined names like 'JohnDoe' instead of separated
    regex = r"\W+"  # remove any non-alphanumeric
    joined_names = list(map(lambda x: re.sub(regex, '', x), chars))
    joined_names = ', '.join(joined_names)
    
    # make unique first and last names
    chars = ', '.join(chars)
    chars = chars.split(', ')
    # print(chars)
    
    # update the set of unique character names 
    #  to remove from synopsis later
    # unique_char_names.update(set(chars))
    return joined_names
    # return np.nan

# %%
# %%timeit
get_char_names(156)
# Out:
# 'ShirouKamui, MonouFuuma, SumeragiSubaru, SakurazukaSeishirou, ArisugawaSorata'

# %%
# @logger.catch
def remove_char_names(row):
    print(row.Characters)
    if 'No synopsis information' in row.synopsis:
        # also remove unnecessary info
        row.synopsis = 'unknown'
        return row
    # print(row)
    anime_name = row.Name
    # regex = get_char_names(anime_name)
    regex = '|'.join(row.Characters.split(','))
    # print(regex)
    # don't need IGNORECASE for names
    row.synopsis = re.sub(regex, '', row.synopsis)
    return row

# %%
specific_animes.MAL_ID.apply(get_char_names, top_k=3)
# Out:
# 237              KurosakiIchigo, KuchikiRukia, AbaraiRenji
# 679             KurosakiIchigo, KuchikiRukia, InoueOrihime
# 731                  KurosakiIchigo, KuchikiRukia, Baishin
# 1468                   KurosakiIchigo, KuchikiRukia, Senna
# 2431     KurosakiIchigo, HitsugayaToushirou, MatsumotoR...
# 3342                 KurosakiIchigo, KuchikiRukia, Shizuku
# 4599             KurosakiIchigo, KuchikiRukia, AbaraiRenji
# 11677     KurosakiIchigo, KuchikiRukia, HitsugayaToushirou
# 13891                                                  NaN
# 15348                                                  NaN
# Name: MAL_ID, dtype: object

# %%
# unique_char_names

# %%
# specific_animes['Characters'] = specific_animes.Name.swifter.apply(get_char_names)
specific_animes['Characters'] = specific_animes.MAL_ID.apply(get_char_names)
# Out:
# <ipython-input-203-be6f6341243e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_animes['Characters'] = specific_animes.MAL_ID.apply(get_char_names)

# %%
# specific_animes.apply(remove_char_names, axis=1)
# Out:
#        MAL_ID                                               Name    Score  \
# 237       269                                             Bleach      7.8
# 679       762                       Bleach: Memories in the Rain     7.15
# 731       834                    Bleach: The Sealed Sword Frenzy     6.98
# 1468     1686                 Bleach Movie 1: Memories of Nobody     7.45
# 2431     2889  Bleach Movie 2: The DiamondDust Rebellion - Mo...     7.45
# 3342     4835  Bleach Movie 3: Fade to Black - Kimi no Na wo ...     7.52
# 4599     8247                         Bleach Movie 4: Jigoku-hen     7.61
# 11677   35118   Bleach KaraBuri!: Gotei Juusan Yatai Daisakusen!     6.51
# 13891   38810                             Bleach: Gotei 13 Omake     6.45
# 15348   41467                          Bleach: Sennen Kessen-hen  Unknown
#
#                                                   Genres  \
# 237    Action, Adventure, Comedy, Super Power, Supern...
# 679      Action, Adventure, Supernatural, Drama, Shounen
# 731    Action, Adventure, Comedy, Super Power, Supern...
# 1468   Action, Adventure, Comedy, Super Power, Supern...
# 2431   Action, Adventure, Comedy, Super Power, Supern...
# 3342   Action, Adventure, Comedy, Super Power, Supern...
# 4599   Action, Adventure, Comedy, Super Power, Supern...
# 11677                                    Comedy, Shounen
# 13891                                  Action, Adventure
# 15348  Action, Adventure, Comedy, Super Power, Supern...
#
#                                                 synopsis  \
# 237      is an ordinary high schooler—until his famil...
# 679     , the temporary Shinigami(Death God) for  , d...
# 731    Shinigami named Baishin who was sealed by Soul...
# 1468   hen a life ends, its soul departs to its final...
# 2431   ssigned to protect a royal procession transpor...
# 3342   fter a mysterious pair attack   and erase her ...
# 4599   "Hell" is the place where a person is sent to ...
# 11677  animated adaptation of several chapters of Col...
# 13891                                            unknown
# 15348                                            unknown
#
#                                                 combined
# 237    Action, Adventure, Comedy, Super Power, Supern...
# 679    Action, Adventure, Supernatural, Drama, Shoune...
# 731    Action, Adventure, Comedy, Super Power, Supern...
# 1468   Action, Adventure, Comedy, Super Power, Supern...
# 2431   Action, Adventure, Comedy, Super Power, Supern...
# 3342   Action, Adventure, Comedy, Super Power, Supern...
# 4599   Action, Adventure, Comedy, Super Power, Supern...
# 11677  Comedy, Shounen animated adaptation of several...
# 13891  Action, Adventure No synopsis information has ...
# 15348  Action, Adventure, Comedy, Super Power, Supern...

# %%
# ! NOTE: This takes quite awhile to finish scraping!
# synopsis_df['Characters'] = synopsis_df.MAL_ID.swifter.apply(get_char_names)
# synopsis_df['Characters'] = synopsis_df.MAL_ID.apply(get_char_names)
# Out:
# Pandas Apply:   0%|          | 0/16206 [00:00<?, ?it/s]

# %%
# synopsis_df.to_csv(DATA_DIR + 'new_synopsis.csv', index=False)

# %%
# if '' in unique_char_names:
#     unique_char_names.remove('')
# with open('data/unique_character_names.pkl', 'wb') as f:
#     pickle.dump(unique_char_names, f)

# %%
pd.Series(list(unique_char_names)).isna().sum()
# Out:
# 0

# %%
synopsis_df['combined'] = synopsis_df['Genres'] + ' ' + synopsis_df['Characters'] + ' ' + synopsis_df['synopsis']

# %%
synopsis_df = pd.read_csv(DATA_DIR + 'new_synopsis.csv')
synopsis_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0     Action, Adventure, Comedy, Drama, SciFi, Space
# 1               Action, Drama, Mystery, SciFi, Space
# 2   Action, SciFi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                             synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...
#
#                                             combined  \
# 0  Action, Adventure, Comedy, Drama, SciFi, Space...
# 1  Action, Drama, Mystery, SciFi, Space SpiegelSp...
# 2  Action, SciFi, Adventure, Comedy, Drama, Shoun...
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4  Adventure, Fantasy, Shounen, Supernatural Beet...
#
#                                           Characters
# 0  SpiegelSpike, ValentineFaye, Wong Hau Pepelu T...
# 1  SpiegelSpike, ValentineFaye, Wong Hau Pepelu T...
# 2  Vash the Stampede, WolfwoodNicholas D., Thomps...
# 3                        SenaRobin, Amon, LeeMichael
# 4                                 Beet, Kissu, Slade

# %%
synopsis_df.loc[synopsis_df.MAL_ID == 156]
# Out:
#      MAL_ID Name Score                                             Genres  \
# 134     156    X  7.43  Action, Super Power, Drama, Magic, Romance, Fa...
#
#                                               synopsis  \
# 134  His destiny has finally arrived as the young S...
#
#                                               combined  \
# 134  Action, Super Power, Drama, Magic, Romance, Fa...
#
#                     Characters
# 134  Ichise, Ran, YoshiiKazuho

# %%
na_char_df = synopsis_df[synopsis_df.Characters.isna()].copy()
na_char_df.shape
# Out:
# (6008, 7)

# %%
print(len(na_char_df[na_char_df.Score == 'Unknown']))
# Out:
# 3819

# %%
print(len(synopsis_df[synopsis_df.Score == 'Unknown']))
# Out:
# 5116

# %%
synopsis_df[synopsis_df.Score == 'Unknown']
# Out:
#        MAL_ID                                               Name    Score  \
# 1347     1547                                   Obake no Q-tarou  Unknown
# 1439     1656                                    PostPet Momobin  Unknown
# 1512     1739                         Shibawanko no Wa no Kokoro  Unknown
# 1619     1863                            Silk Road Shounen Yuuto  Unknown
# 1808     2073  Hengen Taima Yakou Karura Mau! Sendai Kokeshi ...  Unknown
# ...       ...                                                ...      ...
# 16201   48481                    Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16202   48483                                       Mieruko-chan  Unknown
# 16203   48488                    Higurashi no Naku Koro ni Sotsu  Unknown
# 16204   48491                        Yama no Susume: Next Summit  Unknown
# 16205   48492                                      Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 1347         Comedy, School, Slice of Life, Supernatural
# 1439                                        Comedy, Kids
# 1512                                                Kids
# 1619                      Adventure, Fantasy, Historical
# 1808                                      Horror, Shoujo
# ...                                                  ...
# 16201                   Adventure, Mystery, Supernatural
# 16202                       Comedy, Horror, Supernatural
# 16203  Mystery, Dementia, Horror, Psychological, Supe...
# 16204                   Adventure, Slice of Life, Comedy
# 16205                                    Action, Fantasy
#
#                                                 synopsis  \
# 1347   Q-taro, a monster, is living with the Ohara fa...
# 1439   omo and Komomo can deliver mail from anyone, t...
# 1512   Based on a japanese children`s book by Yoshie ...
# 1619   hen a boy Yuto visits Qinghai in China, he is ...
# 1808   Shoko and Maiko Ougi are apparently two ordina...
# ...                                                  ...
# 16201  No synopsis information has been added to this...
# 16202  ko is a typical high school student whose life...
# 16203          Sequel to Higurashi no Naku Koro ni Gou .
# 16204                          New Yama no Susume anime.
# 16205  Solar calendar year 2020: grotesque organisms ...
#
#                                                 combined  \
# 1347   Comedy, School, Slice of Life, Supernatural Q-...
# 1439   Comedy, Kids Komomo, Momo, StrongRock omo and ...
# 1512   Kids Shiba-wanko, Miike-nyanko Based on a japa...
# 1619                                                 NaN
# 1808                                                 NaN
# ...                                                  ...
# 16201                                                NaN
# 16202  Comedy, Horror, Supernatural Miko ko is a typi...
# 16203                                                NaN
# 16204  Adventure, Slice of Life, Comedy YukimuraAoi, ...
# 16205  Action, Fantasy RandallKasane, SumeragiYuito S...
#
#                                   Characters
# 1347             Q-Tarou, OuharaShouta, U-ko
# 1439                Komomo, Momo, StrongRock
# 1512               Shiba-wanko, Miike-nyanko
# 1619                                     NaN
# 1808                                     NaN
# ...                                      ...
# 16201                                    NaN
# 16202                                   Miko
# 16203                                    NaN
# 16204  YukimuraAoi, AobaKokona, KuraueHinata
# 16205           RandallKasane, SumeragiYuito
#
# [5116 rows x 7 columns]

# %%
get_anime_rows(synopsis_df, 'shaman')
# Out:
#        MAL_ID                                    Name    Score  \
# 132       154                             Shaman King     7.78
# 1051     1182                       Shamanic Princess     6.64
# 2968     3861                    Shaman King Specials     7.29
# 3577     5466  Mahoutsukai Tai! vs. Shamanic Princess     5.84
# 14172   39205                                Oshamani  Unknown
# 15550   42205                      Shaman King (2021)  Unknown
#
#                                                   Genres  \
# 132    Action, Adventure, Comedy, Super Power, Supern...
# 1051                     Action, Fantasy, Magic, Romance
# 2968               Action, Comedy, Supernatural, Shounen
# 3577                              Comedy, Magic, Fantasy
# 14172                                               Kids
# 15550  Action, Adventure, Comedy, Super Power, Supern...
#
#                                                 synopsis  \
# 132    attle is about to begin in Tokyo: the Shaman F...
# 1051   From the Guardian World, home of mages, Tiara ...
# 2968   Throughout the broadcast of Shaman King, many ...
# 3577   parody-esque epilogue to both Shamanic Princes...
# 14172  Fashionable, hipster, and ironic--these gruff ...
# 15550  Shamans are extraordinary individuals with the...
#
#                                                 combined  \
# 132    Action, Adventure, Comedy, Super Power, Supern...
# 1051   Action, Fantasy, Magic, Romance Tiara, Lena, G...
# 2968   Action, Comedy, Supernatural, Shounen AsakuraY...
# 3577   Comedy, Magic, Fantasy Tiara, TakakuraTakeo pa...
# 14172                                                NaN
# 15550  Action, Adventure, Comedy, Super Power, Supern...
#
#                              Characters
# 132      AsakuraYou, TaoRen, AsakuraHao
# 1051                Tiara, Lena, Graham
# 2968   AsakuraYou, TaoRen, KyouyamaAnna
# 3577               Tiara, TakakuraTakeo
# 14172                               NaN
# 15550    AsakuraYou, TaoRen, AsakuraHao

# %%
# synopsis_df.to_csv(DATA_DIR + 'new_synopsis.csv', index=False)

# %%
# characters_df = synopsis_df.copy()
# characters_df.Characters.dropna(inplace=True)

# %%
# characters_df.to_csv(DATA_DIR + 'characters.csv', index=False)

# %% [markdown]
# ## Remove unnecessary animes

# %% [markdown]
# - like scores < 7, year < 1990, unknown synopsis etc.

# %%
ori_df = pd.read_csv(DATA_DIR + 'anime_with_synopsis.csv')
ori_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1              Action, Drama, Mystery, Sci-Fi, Space
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                             synopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...

# %%
characters_df = pd.read_csv(DATA_DIR + 'characters.csv')
characters_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres  \
# 0     Action, Adventure, Comedy, Drama, SciFi, Space
# 1               Action, Drama, Mystery, SciFi, Space
# 2   Action, SciFi, Adventure, Comedy, Drama, Shounen
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4          Adventure, Fantasy, Shounen, Supernatural
#
#                                             synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...
#
#                                             combined  \
# 0  Action, Adventure, Comedy, Drama, SciFi, Space...
# 1  Action, Drama, Mystery, SciFi, Space other day...
# 2  Action, SciFi, Adventure, Comedy, Drama, Shoun...
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4  Adventure, Fantasy, Shounen, Supernatural It i...
#
#                                           Characters
# 0  SpiegelSpike, ValentineFaye, Wong Hau Pepelu T...
# 1  SpiegelSpike, ValentineFaye, Wong Hau Pepelu T...
# 2  Vash the Stampede, WolfwoodNicholas D., Thomps...
# 3                        SenaRobin, Amon, LeeMichael
# 4                                 Beet, Kissu, Slade

# %%
characters_df[characters_df.Characters.isna()]
# Out:
# Empty DataFrame
# Columns: [MAL_ID, Name, Score, Genres, synopsis, combined, Characters]
# Index: []

# %%
characters_df = characters_df[characters_df.Characters != ' ']

# %%
characters_df = characters_df[characters_df.Genres != 'Unknown']

# %%
characters_df = characters_df[characters_df.Score != 'Unknown']

# %%
characters_df.shape
# Out:
# (8895, 7)

# %%
characters_df.Score = characters_df.Score.astype(float)

# %%
characters_df = characters_df[characters_df.Score > 6.5]
characters_df.shape
# Out:
# (5529, 7)

# %%
characters_df[characters_df.Score < 7].sort_values('Score', ascending=False).head(20)
# Out:
#        MAL_ID                                               Name  Score  \
# 5106     9712                                  Maria†Holic Alive   6.99
# 12121   35868             Grisaia: Phantom Trigger The Animation   6.99
# 10769   33420                                    RESTART POiNTER   6.99
# 10233   32323                             Aishen Qiaokeli-ing...   6.99
# 324       358                        Iriya no Sora, UFO no Natsu   6.99
# 8796    28617                                         Punch Line   6.99
# 421       461  One Piece Movie 3: Chinjuu-jima no Chopper Oukoku   6.99
# 7062    19023                                    Wake Up, Girls!   6.99
# 6493    16157               Choujigen Game Neptune The Animation   6.99
# 5882    12281                         Rinne no Lagrange Season 2   6.99
# 550       598               Jinzou Ningen Kikaider The Animation   6.99
# 5586    10821  Suite Precure♪ Movie: Torimodose! Kokoro ga Ts...   6.99
# 627       687                                      Tokyo Mew Mew   6.99
# 2853     3656                                  Monochrome Factor   6.99
# 2730     3424                               Porphy no Nagai Tabi   6.99
# 2537     3059                              Ninja Senshi Tobikage   6.99
# 2526     3032         Digimon Tamers: Boukensha-tachi no Tatakai   6.99
# 1620     1864       Koisuru Tenshi Angelique: Kagayaki no Ashita   6.99
# 1442     1659                                 Mai-Otome Specials   6.99
# 1302     1492                                       Project ARMS   6.99
#
#                                                   Genres  \
# 5106                   Comedy, Parody, School, Shoujo Ai
# 12121                                     Action, School
# 10769                                              Music
# 10233                     Harem, Comedy, Romance, School
# 324                                Drama, Romance, SciFi
# 8796     Comedy, Ecchi, SciFi, Super Power, Supernatural
# 421    Action, Adventure, Comedy, Super Power, Fantas...
# 7062                                        Drama, Music
# 6493   Action, Comedy, Fantasy, Parody, SciFi, Supern...
# 5882                        Action, Comedy, Mecha, SciFi
# 550                 Action, SciFi, Drama, Mecha, Shounen
# 5586                        Kids, Magic, Fantasy, Shoujo
# 627       SciFi, Comedy, Magic, Romance, Fantasy, Shoujo
# 2853                    Action, Shounen Ai, Supernatural
# 2730              Drama, Historical, Kids, Slice of Life
# 2537             Adventure, Mecha, SciFi, Shounen, Space
# 2526                    Adventure, Drama, SciFi, Shounen
# 1620              Drama, Fantasy, Harem, Romance, Shoujo
# 1442                       Fantasy, Magic, Comedy, Drama
# 1302                   Action, Martial Arts, Super Power
#
#                                                 synopsis  \
# 5106   hen Kanako Miyamae transferred to a new all-gi...
# 12121  Following the Heath Oslo incident, the existen...
# 10769  Official music video for IDOLiSH7's song "REST...
# 10233  Jiang Hao Yi, a normal, high school student wh...
# 324    saba Naoyuki is an ordinary high school studen...
# 8796   fter escaping a bus hijacking with the help of...
# 421    The crew comes upon Crown Island where the ani...
# 7062   On Christmas 2013, the band Wake Up, Girls pla...
# 6493   fter years of fruitless war between the four r...
# 5882   Several months have passed since Lan and Mugin...
# 550    The genius robotics professor, Dr. Komyoji has...
# 5586   fter Cure Muse's mission of restoring her fath...
# 627    Ichigo Momomiya expected her date with her cru...
# 2853   The story revolves around high school student ...
# 2730   Porfy, his younger sister Mina, and their pare...
# 2537   Ninja Senshi Tobikage tells the story of a boy...
# 2526   Takato and Guilmon go on vacation to Okinawa a...
# 1620   ge is now trapped in the Seijuu Universe, and ...
# 1442        Specials that followed on the Mai-Otome DVD.
# 1302   oy gets involved in an accident when in kinder...
#
#                                                 combined  \
# 5106   Comedy, Parody, School, Shoujo Ai hen Kanako M...
# 12121  Action, School Following the Heath Oslo incide...
# 10769  Music Official music video for IDOLiSH7's song...
# 10233  Harem, Comedy, Romance, School Jiang Hao Yi, a...
# 324    Drama, Romance, SciFi saba Naoyuki is an ordin...
# 8796   Comedy, Ecchi, SciFi, Super Power, Supernatura...
# 421    Action, Adventure, Comedy, Super Power, Fantas...
# 7062   Drama, Music On Christmas 2013, the band Wake ...
# 6493   Action, Comedy, Fantasy, Parody, SciFi, Supern...
# 5882   Action, Comedy, Mecha, SciFi Several months ha...
# 550    Action, SciFi, Drama, Mecha, Shounen The geniu...
# 5586   Kids, Magic, Fantasy, Shoujo fter Cure Muse's ...
# 627    SciFi, Comedy, Magic, Romance, Fantasy, Shoujo...
# 2853   Action, Shounen Ai, Supernatural The story rev...
# 2730   Drama, Historical, Kids, Slice of Life Porfy, ...
# 2537   Adventure, Mecha, SciFi, Shounen, Space Ninja ...
# 2526   Adventure, Drama, SciFi, Shounen Takato and Gu...
# 1620   Drama, Fantasy, Harem, Romance, Shoujo ge is n...
# 1442   Fantasy, Magic, Comedy, Drama Specials that fo...
# 1302   Action, Martial Arts, Super Power oy gets invo...
#
#                                            Characters
# 5106   ShidouMariya, ShinoujiMatsurika, MiyamaeKanako
# 12121      ShishigayaTouka, IkomaMurasaki, FukamiRena
# 10769          NanaseRiku, OusakaSougo, YotsubaTamaki
# 10233              OuyangXueli, XiaZitong, JiangHaoyi
# 324         IriyaKana, AsabaNaoyuki, SuizenjiKunihiro
# 8796     IridatsuYuuta, NaruginoMikatan, HikiotaniIto
# 421                Monkey D.Luffy, RoronoaZoro, Sanji
# 7062         ShimadaMayu, OkamotoMiyu, KatayamaMinami
# 6493                            Neptune, Noire, Blanc
# 5882      KyounoMadoka, Fin E Ld SiLaffinty, Muginami
# 550             Jiro, Saburo/Hakaider, KomyojiMitsuko
# 5586      KurokawaEllen, HoujouHibiki, MinaminoKanade
# 627        MomomiyaIchigo, FujiwaraZakuro, AizawaMint
# 2853           Shirogane, NikaidouAkira, AsamuraKengo
# 2730             PatagosMina, PatagosPorphyras, Elena
# 2537                   MayaJoe, LadorioRomina, AiRene
# 2526                     MakinoRuki, Renamon, Guilmon
# 1620                             Zephel, Ange, Clavis
# 1442           KrugerNatsuki, YumemiyaArika, WángNina
# 1302           TakatsukiRyou, ShinguHayato, KurumaKei

# %%
anime_df.head(2)
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
#
#                                             Genres            English name  \
# 0  Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1            Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
#
#     Japanese name   Type Episodes                        Aired    Premiered  \
# 0       カウボーイビバップ     TV       26  Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1  カウボーイビバップ 天国の扉  Movie        1                  Sep 1, 2001      Unknown
#
#                 Producers                         Licensors  Studios  \
# 0           Bandai Visual  Funimation, Bandai Entertainment  Sunrise
# 1  Sunrise, Bandai Visual       Sony Pictures Entertainment    Bones
#
#      Source         Duration                          Rating Ranked  \
# 0  Original  24 min. per ep.  R - 17+ (violence & profanity)   28.0
# 1  Original    1 hr. 55 min.  R - 17+ (violence & profanity)  159.0
#
#    Popularity  Members  Favorites  Watching  Completed  On-Hold  Dropped  \
# 0          39  1251960      61971    105808     718161    71513    26678
# 1         518   273145       1174      4143     208333     1935      770
#
#    Plan to Watch  Score-10   Score-9   Score-8  Score-7  Score-6 Score-5  \
# 0         329800  229170.0  182126.0  131625.0  62330.0  20688.0  8904.0
# 1          57964   30043.0   49201.0   49505.0  22632.0   5805.0  1877.0
#
#   Score-4 Score-3 Score-2 Score-1
# 0  3184.0  1357.0   741.0  1580.0
# 1   577.0   221.0   109.0   379.0

# %%
characters_df = pd.merge(characters_df, anime_df, on='MAL_ID', suffixes=('', '_y'))
characters_df = characters_df[['MAL_ID', 'Name', 'Type', 'Aired', 'Score', 'Ranked', 'Popularity', 'Genres', 'synopsis', 'combined', 'Characters']]

# %%
characters_df.Aired.str[-4:].value_counts()
# Out:
# 2016    314
# 2015    304
# 2014    291
# 2017    289
# 2018    278
# 2013    278
# 2012    253
# 2011    248
# 2019    246
# 2010    233
# 2007    227
# 2008    225
# 2009    224
# 2006    202
# 2020    196
# 2005    155
# 2004    135
# 2003    132
# 2002    106
# 2001     97
# 1999     87
# 2000     77
# 1998     72
# 1996     70
# 1997     68
# 1995     67
# to ?     57
# 1994     51
# 1993     44
# 1992     44
# 1991     37
# 1986     35
# 1989     35
# 1988     35
# 1987     34
# 1990     34
# 1985     31
# 1984     28
# 1982     22
# 1981     22
# 1983     21
# 1979     20
# 2021     17
# 1980     16
# 1978     15
# 1975     10
# 1976      8
# 1969      7
# 1977      7
# 1974      6
# 1971      5
# 1968      4
# 1973      2
# 1966      2
# 1972      2
# 1964      1
# 1970      1
# 1962      1
# 1961      1
# Name: Aired, dtype: int64

# %%
# len(characters_df[characters_df.Aired.str[-4:] == 'to ?'])
print(len(characters_df[characters_df.Aired.str.contains('?', regex=False)]))
# characters_df[characters_df.Aired.str.contains('?', regex=False)]
# Out:
# 57

# %%
def get_air_date(date_str):
    try:
        date = int(date_str[-4:])
    except:
        # to find the first 4 digits (i.e. year)
        date = int(re.search(r'\d{4}', date_str).group())
    return date

# %%
characters_df.Aired = characters_df.Aired.apply(get_air_date)

# %%
characters_df = characters_df[characters_df.Aired > 1990]

# %%
characters_df.sort_values('Ranked')
# Out:
#       MAL_ID                                               Name   Type  Aired  \
# 2181    5114                   Fullmetal Alchemist: Brotherhood     TV   2010
# 4725   35180                         3-gatsu no Lion 2nd Season     TV   2018
# 4283   31933  JoJo no Kimyou na Bouken Part 4: Diamond wa Ku...     TV   2016
# 3990   28249                                  Arslan Senki (TV)     TV   2015
# 1887    3603            JoJo no Kimyou na Bouken: Phantom Blood  Movie   2007
# ...      ...                                                ...    ...    ...
# 5045   37585                                  Yarichin☆Bitch-bu    OVA   2019
# 552      747                                  Haru wo Daite Ita    OVA   2005
# 5308   39761     Saezuru Tori wa Habatakanai: The Clouds Gather  Movie   2020
# 2670    8634                                     Koisuru Boukun    OVA   2010
# 2288    5774                           Seitokaichou ni Chuukoku    OVA   2010
#
#       Score   Ranked  Popularity  \
# 2181   9.19      1.0           3
# 4725   9.00     10.0         545
# 4283   8.51    100.0         163
# 3990   7.71   1000.0         467
# 1887   7.71   1000.0        2403
# ...     ...      ...         ...
# 5045   6.66  Unknown        2117
# 552    6.76  Unknown        3437
# 5308   7.57  Unknown        3900
# 2670   7.11  Unknown        2086
# 2288   7.05  Unknown        2514
#
#                                                  Genres  \
# 2181  Action, Military, Adventure, Comedy, Drama, Ma...
# 4725                 Drama, Game, Seinen, Slice of Life
# 4283  Action, Adventure, Comedy, Supernatural, Drama...
# 3990  Action, Adventure, Drama, Fantasy, Historical,...
# 1887        Action, Adventure, Horror, Shounen, Vampire
# ...                                                 ...
# 5045                               Comedy, School, Yaoi
# 552                                Drama, Romance, Yaoi
# 5308                                        Drama, Yaoi
# 2670                              Comedy, Romance, Yaoi
# 2288               Comedy, Drama, Romance, School, Yaoi
#
#                                                synopsis  \
# 2181  "In order for something to be obtained, someth...
# 4725  Now in his second year of high school, Rei Kir...
# 4283  The year is 1999. Morioh, a normally quiet and...
# 3990  The year is 320. Under the rule of the bellige...
# 1887  adaptation of the original five volume arc of ...
# ...                                                 ...
# 5045  Takashi Toono was unsure what to expect when h...
# 552   The adorable and attractive main characters of...
# 5308  Yashiro is the young leader of Shinseikai and ...
# 2670  Tetsuhiro Morinaga is in love with his uppercl...
# 2288  Even as he tries to keep the student council p...
#
#                                                combined  \
# 2181  Action, Military, Adventure, Comedy, Drama, Ma...
# 4725  Drama, Game, Seinen, Slice of Life Now in his ...
# 4283  Action, Adventure, Comedy, Supernatural, Drama...
# 3990  Action, Adventure, Drama, Fantasy, Historical,...
# 1887  Action, Adventure, Horror, Shounen, Vampire ad...
# ...                                                 ...
# 5045  Comedy, School, Yaoi Takashi Toono was unsure ...
# 552   Drama, Romance, Yaoi The adorable and attracti...
# 5308  Drama, Yaoi Yashiro is the young leader of Shi...
# 2670  Comedy, Romance, Yaoi Tetsuhiro Morinaga is in...
# 2288  Comedy, Drama, Romance, School, Yaoi Even as h...
#
#                                              Characters
# 2181             ElricEdward, ElricAlphonse, MustangRoy
# 4725         KiriyamaRei, KawamotoHinata, KawamotoAkari
# 4283  KuujouJoutarou, KiraYoshikage, HigashikataJousuke
# 3990                             Arslan, Daryun, Narsus
# 1887         BrandoDio, JoestarJonathan, ZeppeliWill A.
# ...                                                 ...
# 5045                KashimaYuu, ToonoTakashi, YuriAyato
# 552               IwakiKyousuke, KatouYouji, SawaNagisa
# 5308                Yashiro, DoumekiChikara, KugaEishin
# 2670   TatsumiSouichi, MorinagaTetsuhiro, TatsumiKanako
# 2288        ChigaYasuhiro, KokusaiYuuzou, KondouMusashi
#
# [5124 rows x 11 columns]

# %%
characters_df.rename(columns={'Aired': 'Year'}, inplace=True)

# %%
# characters_df.to_csv(DATA_DIR + 'characters_17-May.csv', index=False)

# %%
characters_df = pd.read_csv(DATA_DIR + 'characters_17-May.csv')
characters_df.head()
# Out:
#    MAL_ID                             Name   Type  Year  Score  Ranked  \
# 0       1                     Cowboy Bebop     TV  1999   8.78    28.0
# 1       5  Cowboy Bebop: Tengoku no Tobira  Movie  2001   8.39   159.0
# 2       6                           Trigun     TV  1998   8.24   266.0
# 3       7               Witch Hunter Robin     TV  2002   7.27  2481.0
# 4       8                   Bouken Ou Beet     TV  2005   6.98  3710.0
#
#    Popularity                                             Genres  \
# 0          39     Action, Adventure, Comedy, Drama, SciFi, Space
# 1         518               Action, Drama, Mystery, SciFi, Space
# 2         201   Action, SciFi, Adventure, Comedy, Drama, Shounen
# 3        1467  Action, Mystery, Police, Supernatural, Drama, ...
# 4        4369          Adventure, Fantasy, Shounen, Supernatural
#
#                                             synopsis  \
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  ches are individuals with special powers like ...
# 4  It is the dark century and the people are suff...
#
#                                             combined  \
# 0  Action, Adventure, Comedy, Drama, SciFi, Space...
# 1  Action, Drama, Mystery, SciFi, Space other day...
# 2  Action, SciFi, Adventure, Comedy, Drama, Shoun...
# 3  Action, Mystery, Police, Supernatural, Drama, ...
# 4  Adventure, Fantasy, Shounen, Supernatural It i...
#
#                                           Characters
# 0  SpiegelSpike, ValentineFaye, Wong Hau Pepelu T...
# 1  SpiegelSpike, ValentineFaye, Wong Hau Pepelu T...
# 2  Vash the Stampede, WolfwoodNicholas D., Thomps...
# 3                        SenaRobin, Amon, LeeMichael
# 4                                 Beet, Kissu, Slade

# %%
characters_df.shape, ori_df.shape
# Out:
# ((5124, 10), (16214, 5))

# %%
# characters_df['combined'] = characters_df['Genres'] + ' ' + characters_df['Characters'] + ' '

# %% [markdown]
# ## Get all character names

# %%
characters_df.Characters = characters_df.MAL_ID.apply(get_char_names, top_k=10)

# %%
characters_df.Characters[:5]
# Out:
# 0    SpiegelSpike, ValentineFaye, WongHauPepeluTivr...
# 1    SpiegelSpike, ValentineFaye, WongHauPepeluTivr...
# 2    VashtheStampede, WolfwoodNicholasD, ThompsonMi...
# 3    SenaRobin, Amon, LeeMichael, SakakiHaruto, Kar...
# 4    Beet, Kissu, Slade, Milfa, Poala, Zenon, Shagg...
# Name: Characters, dtype: object

# %%
len(characters_df[characters_df.Characters.isna()])
# Out:
# 9

# %%
characters_df.dropna(inplace=True)
characters_df.reset_index(inplace=True, drop=True)

# %%
# characters_df.to_csv(DATA_DIR + 'filtered_full_char_names.csv', index=False)

# %%
def separate_char_names(name):
    # name = 'Saber, ToosakaRin, Archer'
    name = name.replace(', ', '')
    name_list = re.findall('[A-Z]{1}[^A-Z]+', name)
    name_list = [txt.strip() for txt in name_list]
    return name_list

# %%
characters_df['char_name_list'] = characters_df.Characters.apply(separate_char_names)

# %%
characters_df.combined = characters_df.char_name_list.apply(str) + ' ' + characters_df.synopsis
characters_df.combined[0]
# Out:
# '[\'Spiegel\', \'Spike\', \'Valentine\', \'Faye\', \'Wong\', \'Hau\', \'Pepelu\', \'Tivrusky\', \'Edward\', \'Black\', \'Jet\', \'Ein\', \'Vicious\', \'Julia\', \'Eckener\', \'Grencia\', \'Mars\', \'Elijah\', \'Guo\', \'Vonde\', \'Oniyate\', \'Andy\', \'Mad\', \'Pierrot\'] In the year 2071, humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet Earth behind. The Inter Solar System Police attempts to keep peace in the galaxy, aided in part by outlaw bounty hunters, referred to as "Cowboys." The ragtag team aboard the spaceship Bebop are two such individuals. Mellow and carefree Spike Spiegel is balanced by his boisterous, pragmatic partner Jet Black as the pair makes a living chasing bounties and collecting rewards. Thrown off course by the addition of new members that they meet in their travels—Ein, a genetically engineered, highly intelligent Welsh Corgi; femme fatale Faye Valentine, an enigmatic trickster with memory loss; and the strange computer whiz kid Edward Wong—the crew embarks on thrilling adventures that unravel each member\'s dark and mysterious past little by little. Well-balanced with high density action and light-hearted comedy, Cowboy Bebop is a space Western classic and an homage to the smooth and improvised music it is named after.'

# %%
def remove_names(text):
    # text.split(']')[0]
    idx = re.search(r']', text).span()[1] + 1
    name_list = eval(text[:idx])
    text = text[idx:]
    regex = '|'.join(name_list)
    text = re.sub(regex, '', text)
    return text

# %%
characters_df.combined = characters_df.combined.apply(remove_names)

# %%
idx = 1
display(characters_df.loc[[idx]])
print(characters_df.combined.loc[idx])
# Out:
#    index  MAL_ID                             Name   Type  Year  Score Ranked  \
# 1      1       5  Cowboy Bebop: Tengoku no Tobira  Movie  2001   8.39  159.0
#
#    Popularity                                Genres  \
# 1         518  Action, Drama, Mystery, SciFi, Space
#
#                                             synopsis  \
# 1  other day, another bounty—such is the life of ...
#
#                                             combined  \
# 1  other day, another bounty—such is the life of ...
#
#                                           Characters  \
# 1  SpiegelSpike, ValentineFaye, WongHauPepeluTivr...
#
#                                       char_name_list
# 1  [Spiegel, Spike, Valentine, Faye, Wong, Hau, P...
# other day, another bounty—such is the life of the often unlucky crew of the Bebop. However, this routine is interrupted when , who is chasing a fairly worthless target on Mars, witnesses an oil tanker suddenly explode, causing mass hysteria. As casualties mount due to a strange disease spreading through the smoke from the blast, a whopping three hundred million woolong price is placed on the head of the supposed perpetrator. With lives at stake and a solution to their money problems in sight, the Bebop crew springs into action. , , , and , followed closely by , split up to pursue different leads across Alba City. Through their individual investigations, they discover a cover-up scheme involving a pharmaceutical company, revealing a plot that reaches much further than the ragtag team of bounty hunters could have realized.

# %%
characters_df.combined[id_to_idx(269)]
# Out:
# "  is an ordinary high schooler—until his family is attacked by a Hollow, a corrupt spirit that seeks to devour human souls. It is then that he meets a Soul Reaper named  , who gets injured while protecting 's family from the assailant. To save his family,  accepts 's offer of taking her powers and becomes a Soul Reaper as a result. However, as  is unable to regain her powers,  is given the daunting task of hunting down the Hollows that plague their town. However, he is not alone in his fight, as he is later joined by his friends—classmates  ,  , and  —who each have their own unique abilities. As  and his comrades get used to their new duties and support each other on and off the battlefield, the young Soul Reaper soon learns that the Hollows are not the only real threat to the human world."

# %%
characters_df['combined'] = characters_df['Genres'] + ' ' + characters_df['Characters'] + ' ' + characters_df['combined']

# %%
characters_df['genre_and_char'] = characters_df['Genres'] + ' ' + characters_df['Characters']

# %%
characters_df.combined[id_to_idx(269)]
# Out:
# "Action, Adventure, Comedy, Super Power, Supernatural, Shounen KurosakiIchigo, KuchikiRukia, AbaraiRenji, InoueOrihime, IshidaUryuu, SadoYasutora, ZarakiKenpachi, HitsugayaToushirou, CiferUlquiorra, UraharaKisuke   is an ordinary high schooler—until his family is attacked by a Hollow, a corrupt spirit that seeks to devour human souls. It is then that he meets a Soul Reaper named  , who gets injured while protecting 's family from the assailant. To save his family,  accepts 's offer of taking her powers and becomes a Soul Reaper as a result. However, as  is unable to regain her powers,  is given the daunting task of hunting down the Hollows that plague their town. However, he is not alone in his fight, as he is later joined by his friends—classmates  ,  , and  —who each have their own unique abilities. As  and his comrades get used to their new duties and support each other on and off the battlefield, the young Soul Reaper soon learns that the Hollows are not the only real threat to the human world."

# %%
# characters_df.to_csv(DATA_DIR + 'filtered_full_char_names.csv', index=False)

# %% [markdown]
# - ! OR TRY add the character names to stopwords to remove in TfidVectorizer

# %%
stopwords_set = set(stopwords.words('english'))
print(stopwords_set)
# Out:
# {'in', 'wasn', "should've", 'and', 'you', 'now', "mightn't", 'its', "needn't", 'those', 'as', 'out', 'only', "haven't", 'won', 'for', 'her', "wasn't", 're', 'to', 'ourselves', 'ain', 'own', 'on', 'if', "wouldn't", 'each', 't', "that'll", 'both', 'off', 'theirs', 'about', 'such', 'that', 'again', 'whom', 'me', 'he', 'it', 'are', "it's", 'this', 'we', 'couldn', 'but', 'more', 'doing', 'or', "hasn't", 'any', "mustn't", "doesn't", 'was', "isn't", 'other', "don't", 've', 'some', "shouldn't", 'them', 'yourselves', 'their', 'until', 'shan', 'having', 'through', 'do', 'at', 'shouldn', 'up', 'under', 'haven', "she's", 'she', 'same', 'doesn', "won't", 'when', 'does', 'hasn', 'into', 'been', 'hers', 'just', 'how', 'yours', 'll', 'before', 'few', 'what', 'mustn', 'down', 'y', 'ma', 'isn', 'be', 'were', 'him', 'during', 'am', 'itself', 'ours', 'don', 'd', 'nor', 'they', 'has', 'have', 'once', 'hadn', 'which', 'i', 'his', 'these', "hadn't", 'where', 'aren', 'is', 'himself', 'over', 'there', 's', "you'll", 'then', "you're", 'after', "didn't", 'while', "shan't", 'of', 'being', "you've", 'themselves', "couldn't", 'yourself', 'than', 'needn', 'can', 'herself', 'between', 'why', 'an', 'from', 'here', 'above', 'very', 'didn', "weren't", 'did', 'weren', 'by', 'further', 'had', 'too', 'will', 'not', 'your', 'mightn', 'with', 'the', "aren't", 'm', 'most', 'should', 'wouldn', 'o', 'our', 'no', 'a', 'who', 'against', 'below', 'myself', 'all', 'so', 'my', 'because', "you'd"}

# %%
# unique_char_names = pickle.load(open('data/unique_character_names.pkl', 'rb'))
# unique_char_names = set([x.lower() for x in unique_char_names])

# stopwords_set.update(unique_char_names)

# %%
regex = '|'.join(unique_char_names)
# synopsis_df.Name.str.replace(regex, '', case=False, regex=True)

# %%
# %%timeit
# adding flag will double the time, but don't need IGNORECASE for names
re.sub(regex, '', synopsis_df.synopsis[2])
# Out:
# 49.2 ms ± 301 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
synopsis_df.iloc[:1].apply(remove_char_names, axis=1)
# Out:
# 1.54 ms ± 11.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
specific_animes.apply(remove_char_names, axis=1)
# Out:
# KurosakiIchigo, KuchikiRukia
# KurosakiIchigo, KuchikiRukia
# KurosakiIchigo, KuchikiRukia
# KurosakiIchigo, KuchikiRukia
# KurosakiIchigo, HitsugayaToushirou
# KurosakiIchigo, KuchikiRukia
# KurosakiIchigo, KuchikiRukia
# KurosakiIchigo, KuchikiRukia
# nan
# nan
#        MAL_ID                                               Name    Score  \
# 237       269                                             Bleach      7.8
# 679       762                       Bleach: Memories in the Rain     7.15
# 731       834                    Bleach: The Sealed Sword Frenzy     6.98
# 1468     1686                 Bleach Movie 1: Memories of Nobody     7.45
# 2431     2889  Bleach Movie 2: The DiamondDust Rebellion - Mo...     7.45
# 3342     4835  Bleach Movie 3: Fade to Black - Kimi no Na wo ...     7.52
# 4599     8247                         Bleach Movie 4: Jigoku-hen     7.61
# 11677   35118   Bleach KaraBuri!: Gotei Juusan Yatai Daisakusen!     6.51
# 13891   38810                             Bleach: Gotei 13 Omake     6.45
# 15348   41467                          Bleach: Sennen Kessen-hen  Unknown
#
#                                                   Genres  \
# 237    Action, Adventure, Comedy, Super Power, Supern...
# 679      Action, Adventure, Supernatural, Drama, Shounen
# 731    Action, Adventure, Comedy, Super Power, Supern...
# 1468   Action, Adventure, Comedy, Super Power, Supern...
# 2431   Action, Adventure, Comedy, Super Power, Supern...
# 3342   Action, Adventure, Comedy, Super Power, Supern...
# 4599   Action, Adventure, Comedy, Super Power, Supern...
# 11677                                    Comedy, Shounen
# 13891                                  Action, Adventure
# 15348  Action, Adventure, Comedy, Super Power, Supern...
#
#                                                 synopsis  \
# 237    Ichigo Kurosaki is an ordinary high schooler—u...
# 679    Kurosaki Ichigo, the temporary Shinigami(Death...
# 731    Shinigami named Baishin who was sealed by Soul...
# 1468   hen a life ends, its soul departs to its final...
# 2431   ssigned to protect a royal procession transpor...
# 3342   fter a mysterious pair attack Rukia Kuchiki an...
# 4599   "Hell" is the place where a person is sent to ...
# 11677  animated adaptation of several chapters of Col...
# 13891                                            unknown
# 15348                                            unknown
#
#                                                 combined  \
# 237    Action, Adventure, Comedy, Super Power, Supern...
# 679    Action, Adventure, Supernatural, Drama, Shoune...
# 731    Action, Adventure, Comedy, Super Power, Supern...
# 1468   Action, Adventure, Comedy, Super Power, Supern...
# 2431   Action, Adventure, Comedy, Super Power, Supern...
# 3342   Action, Adventure, Comedy, Super Power, Supern...
# 4599   Action, Adventure, Comedy, Super Power, Supern...
# 11677  Comedy, Shounen animated adaptation of several...
# 13891  Action, Adventure No synopsis information has ...
# 15348  Action, Adventure, Comedy, Super Power, Supern...
#
#                                Characters
# 237          KurosakiIchigo, KuchikiRukia
# 679          KurosakiIchigo, KuchikiRukia
# 731          KurosakiIchigo, KuchikiRukia
# 1468         KurosakiIchigo, KuchikiRukia
# 2431   KurosakiIchigo, HitsugayaToushirou
# 3342         KurosakiIchigo, KuchikiRukia
# 4599         KurosakiIchigo, KuchikiRukia
# 11677        KurosakiIchigo, KuchikiRukia
# 13891                                 NaN
# 15348                                 NaN

# %%
# %%timeit
synopsis_df.loc[:1, 'synopsis'].str.replace(regex, '', regex=True)
# Out:
# 91.8 ms ± 188 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# need about 40 mins to finish replacing with re.sub
48.9 * 1e-3 * 48492 / 60
# Out:
# 39.52098

# %% [markdown]
# # Recommendation system modelling

# %%
# get_char_names(33840)

# %%
text = 'Grim Reaper'
text.lower() in stopwords_set
# Out:
# True

# %%
print(sorted(stopwords_set))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 'if', 'in', 'into', 'is', 'isn', "isn't", 'it', "it's", 'its', 'itself', 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she's", 'should', "should've", 'shouldn', "shouldn't", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', 'were', 'weren', "weren't", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves']

# %%
capital_stopwords = [x.capitalize() for x in stopwords_set]
stopwords_list = list(stopwords_set)
stopwords_list.extend(capital_stopwords)
cap_stopwords_set = set(stopwords_list)
print(sorted(cap_stopwords_set))
# Out:
# ['A', 'About', 'Above', 'After', 'Again', 'Against', 'Ain', 'All', 'Am', 'An', 'And', 'Any', 'Are', 'Aren', "Aren't", 'As', 'At', 'Be', 'Because', 'Been', 'Before', 'Being', 'Below', 'Between', 'Both', 'But', 'By', 'Can', 'Couldn', "Couldn't", 'D', 'Did', 'Didn', "Didn't", 'Do', 'Does', 'Doesn', "Doesn't", 'Doing', 'Don', "Don't", 'Down', 'During', 'Each', 'Few', 'For', 'From', 'Further', 'Had', 'Hadn', "Hadn't", 'Has', 'Hasn', "Hasn't", 'Have', 'Haven', "Haven't", 'Having', 'He', 'Her', 'Here', 'Hers', 'Herself', 'Him', 'Himself', 'His', 'How', 'I', 'If', 'In', 'Into', 'Is', 'Isn', "Isn't", 'It', "It's", 'Its', 'Itself', 'Just', 'Ll', 'M', 'Ma', 'Me', 'Mightn', "Mightn't", 'More', 'Most', 'Mustn', "Mustn't", 'My', 'Myself', 'Needn', "Needn't", 'No', 'Nor', 'Not', 'Now', 'O', 'Of', 'Off', 'On', 'Once', 'Only', 'Or', 'Other', 'Our', 'Ours', 'Ourselves', 'Out', 'Over', 'Own', 'Re', 'S', 'Same', 'Shan', "Shan't", 'She', "She's", 'Should', "Should've", 'Shouldn', "Shouldn't", 'So', 'Some', 'Such', 'T', 'Than', 'That', "That'll", 'The', 'Their', 'Theirs', 'Them', 'Themselves', 'Then', 'There', 'These', 'They', 'This', 'Those', 'Through', 'To', 'Too', 'Under', 'Until', 'Up', 'Ve', 'Very', 'Was', 'Wasn', "Wasn't", 'We', 'Were', 'Weren', "Weren't", 'What', 'When', 'Where', 'Which', 'While', 'Who', 'Whom', 'Why', 'Will', 'With', 'Won', "Won't", 'Wouldn', "Wouldn't", 'Y', 'You', "You'd", "You'll", "You're", "You've", 'Your', 'Yours', 'Yourself', 'Yourselves', 'a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 'if', 'in', 'into', 'is', 'isn', "isn't", 'it', "it's", 'its', 'itself', 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she's", 'should', "should've", 'shouldn', "shouldn't", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', 'were', 'weren', "weren't", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves']

# %%
# vectorizer = TfidfVectorizer(min_df=1, ngram_range=(1, 1), lowercase=False, stop_words=stopwords_set)
vectorizer = TfidfVectorizer(min_df=1, ngram_range=(1, 1), lowercase=False, stop_words=cap_stopwords_set)
# tfid_matrix = vectorizer.fit_transform(characters_df['combined'])
tfid_matrix = vectorizer.fit_transform(characters_df['genre_and_char'])
tfid_matrix.shape
# Out:
# (5115, 22558)

# %%
# vectorizer = CountVectorizer(min_df=1, lowercase=False, stop_words=cap_stopwords_set)
# tfid_matrix = vectorizer.fit_transform(characters_df['combined'])
# tfid_matrix.shape

# %%
cos = cosine_similarity(tfid_matrix, tfid_matrix)
cos.shape
# Out:
# (5115, 5115)

# %%
def id_to_idx(anime_id):
    return characters_df.loc[characters_df.MAL_ID == anime_id].index[0]

def idx_to_id(anime_idx):
    return characters_df.loc[anime_idx, 'MAL_ID']

# %%
# anime_id = 269  # bleach
anime_id = 269
def check_anime(anime_id, return_words=False, verbose=1):
    anime_idx = id_to_idx(anime_id)
    words = sorted(vectorizer.inverse_transform(tfid_matrix[anime_idx])[0])
    display(characters_df.loc[[anime_idx]])
    if verbose:
        print("Synopsis:", characters_df.loc[anime_idx, 'synopsis'])
        print(words)
    if return_words:
        return words
check_anime(anime_id)
# Out:
#      MAL_ID    Name Type  Year  Score Ranked  Popularity  \
# 207     269  Bleach   TV  2012    7.8  818.0          33
#
#                                                 Genres  \
# 207  Action, Adventure, Comedy, Super Power, Supern...
#
#                                               synopsis  \
# 207  Ichigo Kurosaki is an ordinary high schooler—u...
#
#                                               combined  \
# 207  Action, Adventure, Comedy, Super Power, Supern...
#
#                                             Characters  \
# 207  KurosakiIchigo, KuchikiRukia, AbaraiRenji, Ino...
#
#                                         char_name_list
# 207  [Kurosaki, Ichigo, Kuchiki, Rukia, Abarai, Ren...
# Synopsis: Ichigo Kurosaki is an ordinary high schooler—until his family is attacked by a Hollow, a corrupt spirit that seeks to devour human souls. It is then that he meets a Soul Reaper named Rukia Kuchiki, who gets injured while protecting Ichigo's family from the assailant. To save his family, Ichigo accepts Rukia's offer of taking her powers and becomes a Soul Reaper as a result. However, as Rukia is unable to regain her powers, Ichigo is given the daunting task of hunting down the Hollows that plague their town. However, he is not alone in his fight, as he is later joined by his friends—classmates Orihime Inoue, Yasutora Sado, and Uryuu Ishida—who each have their own unique abilities. As Ichigo and his comrades get used to their new duties and support each other on and off the battlefield, the young Soul Reaper soon learns that the Hollows are not the only real threat to the human world.
# ['AbaraiRenji', 'Action', 'Adventure', 'CiferUlquiorra', 'Comedy', 'HitsugayaToushirou', 'Hollow', 'Hollows', 'However', 'InoueOrihime', 'IshidaUryuu', 'KuchikiRukia', 'KurosakiIchigo', 'Power', 'Reaper', 'SadoYasutora', 'Shounen', 'Soul', 'Super', 'Supernatural', 'UraharaKisuke', 'ZarakiKenpachi', 'abilities', 'accepts', 'alone', 'assailant', 'attacked', 'battlefield', 'becomes', 'classmates', 'comrades', 'corrupt', 'daunting', 'devour', 'duties', 'family', 'fight', 'friends', 'get', 'gets', 'given', 'high', 'human', 'hunting', 'injured', 'joined', 'later', 'learns', 'meets', 'named', 'new', 'offer', 'ordinary', 'plague', 'powers', 'protecting', 'real', 'regain', 'result', 'save', 'schooler', 'seeks', 'soon', 'souls', 'spirit', 'support', 'taking', 'task', 'threat', 'town', 'unable', 'unique', 'used', 'world', 'young']

# %%
characters_df.loc[anime_idx]
# Out:
# MAL_ID                                                       20
# Name                                                     Naruto
# Year                                                       2007
# Score                                                      7.91
# Ranked                                                    660.0
# Popularity                                                    8
# Genres        Action, Adventure, Comedy, Super Power, Martia...
# synopsis      oments prior to Naruto Uzumaki's birth, a huge...
# combined      Action, Adventure, Comedy, Super Power, Martia...
# Characters           UzumakiNaruto, HatakeKakashi, UchihaSasuke
# Name: 10, dtype: object

# %%
all_anime_types = set(characters_df.Type.unique())

@logger.catch
def get_recommendation(anime_name, top_k=10, anime_types='TV', popular=False):
    df = characters_df.copy()
    # get the index of the anime row
    try:
        anime_idx = get_anime_rows(df, anime_name).index[0]
    except:
        raise Exception('Anime not found!')
    print(f"Recommending Animes for: {df.loc[anime_idx, 'Name']} ...")
    # generate a list of tuples of (index, cosine_scores) for the anime
    cosine_scores = list(enumerate(cos[anime_idx]))
    # sort by the highest similarity
    cosine_scores = sorted(cosine_scores, key=lambda x: x[1], reverse=True)
    # get the indices for the sorted animes
    anime_indices = [x[0] for x in cosine_scores]
    # get the df rows for the sorted animes
    df = df.loc[anime_indices]
    if popular:
        df = df[df.Popularity < 2500]
    if anime_types == 'all':
        pass
    elif isinstance(anime_types, (str, tuple, list)):
        anime_types = set([anime_types]) if isinstance(anime_types, str) else set(anime_types)
        assert anime_types.issubset(all_anime_types), 'Anime type does not exist'
        df = df[df.Type.isin(anime_types)]
    else:
        raise Exception('Type of anime_types variable is not valid.')
    # return only the top k recommended animes
    return df.iloc[0:top_k + 1]

# %% [markdown]
# - !! MAYBE can try to sort the recommended animes by Score

# %%
check_anime(356)
# Out:
#      MAL_ID             Name Type  Year  Score  Ranked  Popularity  \
# 265     356  Fate/stay night   TV  2006   7.34  2152.0         119
#
#                                             Genres  \
# 265  Action, Supernatural, Magic, Romance, Fantasy
#
#                                               synopsis  \
# 265  fter a mysterious inferno kills his family, Sh...
#
#                                               combined  \
# 265  Action, Supernatural, Magic, Romance, Fantasy ...
#
#                                             Characters  \
# 265  Saber, ToosakaRin, Archer, EmiyaShirou, EmiyaK...
#
#                                         char_name_list
# 265  [Saber, Toosaka, Rin, Archer, Emiya, Shirou, E...
# Synopsis: fter a mysterious inferno kills his family, Shirou is saved and adopted by Kiritsugu Emiya, who teaches him the ways of magic and justice. One night, years after Kiritsugu's death, Shirou is cleaning at school, when he finds himself caught in the middle of a deadly encounter between two superhumans known as Servants. During his attempt to escape, the boy is caught by one of the Servants and receives a life-threatening injury. Miraculously, he survives, but the same Servant returns to finish what he started. In desperation, Shirou summons a Servant of his own, a knight named Saber. The two must now participate in the Fifth Holy Grail War, a battle royale of seven Servants and the mages who summoned them, with the grand prize being none other than the omnipotent Holy Grail itself. Fate/stay night follows Shirou as he struggles to find the fine line between a hero and a killer, his ideals clashing with the harsh reality around him. Will the boy become a hero like his foster father, or die trying?
# ['Action', 'Archer', 'EmiyaKiritsugu', 'EmiyaShirou', 'Fantasy', 'Fate', 'Fifth', 'Gilgamesh', 'Grail', 'Holy', 'KotomineKirei', 'Lancer', 'Magic', 'MatouSakura', 'Miraculously', 'One', 'Romance', 'Saber', 'Servant', 'Servants', 'Supernatural', 'ToosakaRin', 'War', 'adopted', 'around', 'attempt', 'battle', 'become', 'boy', 'caught', 'clashing', 'cleaning', 'deadly', 'death', 'desperation', 'die', 'encounter', 'escape', 'family', 'father', 'find', 'finds', 'fine', 'finish', 'follows', 'foster', 'fter', 'grand', 'harsh', 'hero', 'ideals', 'inferno', 'injury', 'justice', 'killer', 'kills', 'knight', 'known', 'life', 'like', 'line', 'mages', 'magic', 'middle', 'must', 'mysterious', 'named', 'night', 'none', 'omnipotent', 'one', 'participate', 'prize', 'reality', 'receives', 'returns', 'royale', 'saved', 'school', 'seven', 'started', 'stay', 'struggles', 'summoned', 'summons', 'superhumans', 'survives', 'teaches', 'threatening', 'trying', 'two', 'vonEinzbernIllyasviel', 'ways', 'years']

# %%
check_anime(11783)
# Out:
#       MAL_ID       Name Type  Year  Score  Ranked  Popularity  \
# 2679   11783  Dog Days'   TV  2012   7.09  3248.0        1544
#
#                                  Genres  \
# 2679  Action, Adventure, Magic, Fantasy
#
#                                                synopsis  \
# 2679  Cinque returns to the land of Flonyard in Dog ...
#
#                                                combined  \
# 2679  Action, Adventure, Magic, Fantasy FiriannoBisc...
#
#                                              Characters  \
# 2679  FiriannoBiscottiMillhiore, MartinozziÉclair, G...
#
#                                          char_name_list
# 2679  [Firianno, Biscotti, Millhiore, MartinozziÉcla...
# Synopsis: Cinque returns to the land of Flonyard in Dog Days' to resume his duties as the hero of the Biscotti Republic and it's as though he never left! The difference this time is that he's brought two friends with him who become heroes in their own right: childhood best friend Rebecca Anderson, who becomes the hero for the Principality of Pastillage at the urging of their leader Princess Couvert Eschenbach Pastillage, and his cousin Nanami Takatsuki, who becomes the hero for the Galette Lion Dominion. As with the first season though, with so many secrets to be uncovered and mysteries to be solved, will there even be time for the athletic events that these three hyper and athletic teenagers love to participate in so much?
# ['Action', 'Adventure', 'AndersonRebecca', 'Days', 'Dog', 'Dominion', 'ElmarRicotta', 'EschenbachPastillageCouvert', 'Fantasy', 'FiriannoBiscottiMillhiore', 'Flonyard', 'Galette', 'GalettedesRoisLeonmitchelli', 'IzumiCinque', 'Lion', 'Magic', 'MartinozziÉclair', 'PanettoneYukikaze', 'Princess', 'Principality', 'Republic', 'TakatsukiNanami', 'athletic', 'become', 'becomes', 'best', 'brought', 'childhood', 'cousin', 'dArquienBrioche', 'difference', 'duties', 'even', 'events', 'first', 'friend', 'friends', 'hero', 'heroes', 'hyper', 'land', 'leader', 'left', 'love', 'many', 'much', 'mysteries', 'never', 'participate', 'resume', 'returns', 'right', 'season', 'secrets', 'solved', 'teenagers', 'though', 'three', 'time', 'two', 'uncovered', 'urging']

# %%
def compare_anime(anime_id, anime_id_recommended):
    words_1 = check_anime(anime_id, return_words=True, verbose=0)
    words_rec = check_anime(anime_id_recommended, return_words=True, verbose=0)
    total = 0
    for item in words_1:
        if item in words_rec:
            total += 1
    return f"Total same words found = {total}"

# %%
compare_anime(356, 10087)
# Out:
#      MAL_ID             Name Type  Year  Score  Ranked  Popularity  \
# 265     356  Fate/stay night   TV  2006   7.34  2152.0         119
#
#                                             Genres  \
# 265  Action, Supernatural, Magic, Romance, Fantasy
#
#                                               synopsis  \
# 265  fter a mysterious inferno kills his family, Sh...
#
#                                               combined  \
# 265  Action, Supernatural, Magic, Romance, Fantasy ...
#
#                                             Characters  \
# 265  Saber, ToosakaRin, Archer, EmiyaShirou, EmiyaK...
#
#                                         char_name_list
# 265  [Saber, Toosaka, Rin, Archer, Emiya, Shirou, E...
#       MAL_ID       Name Type  Year  Score Ranked  Popularity  \
# 2453   10087  Fate/Zero   TV  2011   8.34  192.0          59
#
#                                     Genres  \
# 2453  Action, Supernatural, Magic, Fantasy
#
#                                                synopsis  \
# 2453  h the promise of granting any wish, the omnipo...
#
#                                                combined  \
# 2453  Action, Supernatural, Magic, Fantasy Saber, Em...
#
#                                              Characters  \
# 2453  Saber, EmiyaKiritsugu, Gilgamesh, KotomineKire...
#
#                                          char_name_list
# 2453  [Saber, Emiya, Kiritsugu, Gilgamesh, Kotomine,...
# 'Total same words found = 37'

# %%
get_recommendation('subarashi', top_k=30, anime_types=('TV'))
# get_recommendation('fate', top_k=30, anime_types=('TV'), popular=1)
# Out:
# Recommending Animes for: Kono Subarashii Sekai ni Shukufuku wo! ...
#       MAL_ID                                      Name Type  Year  Score  \
# 3738   30831    Kono Subarashii Sekai ni Shukufuku wo!   TV  2016   8.15
# 3996   32937  Kono Subarashii Sekai ni Shukufuku wo! 2   TV  2017   8.31
# 4758   38472                            Isekai Quartet   TV  2019   7.45
# 4912   39988                          Isekai Quartet 2   TV  2020   7.38
# 2577   10790       Kore wa Zombie Desu ka? of the Dead   TV  2012   7.56
# 515      738                                       MÄR   TV  2007   7.28
# 516      740             Bishoujo Senshi Sailor Moon R   TV  1994   7.69
# 395      530               Bishoujo Senshi Sailor Moon   TV  1993   7.68
# 1969    6166                          Asobi ni Iku yo!   TV  2010   6.65
# 3503   25731       Cross Ange: Tenshi to Ryuu no Rondo   TV  2015   7.41
# 136      178                              Ultra Maniac   TV  2003   7.18
# 505      709                     Mujin Wakusei Survive   TV  2004   7.71
# 902     1502          Mahou Shoujo Pretty Sammy (1996)   TV  1997   6.73
# 713     1103                 Shinkon Gattai Godannar!!   TV  2003   6.69
# 714     1104      Shinkon Gattai Godannar!! 2nd Season   TV  2004   6.95
# 1859    5343   Monkey Punch: Manga Katsudou Daishashin   TV  2005   6.90
# 1154    2041      Ai to Yuuki no Pig Girl Tonde Buurin   TV  1995   6.63
# 2364    9493                Dororon Enma-kun Meeramera   TV  2011   6.53
# 1223    2259                     Dr. Rin ni Kiitemite!   TV  2002   6.79
# 928     1546                                  Negima!?   TV  2007   7.02
# 2978   16157      Choujigen Game Neptune The Animation   TV  2013   6.99
# 189      249                                  InuYasha   TV  2004   7.85
# 2068    6811                    InuYasha: Kanketsu-hen   TV  2010   8.22
# 5074   41911  Hanyou no Yashahime: Sengoku Otogizoushi   TV  2020   6.86
# 434      592                               PopoloCrois   TV  2004   6.93
# 3918   32230                                 Xi You Ji   TV  1999   6.89
# 135      177                         Tsubasa Chronicle   TV  2005   7.55
# 1381    2783                   Oyayubi Hime Monogatari   TV  1992   6.67
# 4245   34577   Nanatsu no Taizai: Imashime no Fukkatsu   TV  2018   7.84
# 5064   41491       Nanatsu no Taizai: Fundo no Shinpan   TV  2021   7.16
# 3848   31722     Nanatsu no Taizai: Seisen no Shirushi   TV  2016   7.12
#
#       Ranked  Popularity                                             Genres  \
# 3738   363.0          34  Adventure, Comedy, Fantasy, Magic, Parody, Sup...
# 3996   225.0          69  Adventure, Comedy, Parody, Supernatural, Magic...
# 4758  1736.0         510                            Comedy, Fantasy, Parody
# 4912  2002.0         951                            Comedy, Parody, Fantasy
# 2577  1392.0         432  Action, Harem, Comedy, Supernatural, Magic, Ecchi
# 515   2455.0        2427        Action, Adventure, Comedy, Fantasy, Shounen
# 516   1051.0        1213                     Demons, Magic, Romance, Shoujo
# 395   1070.0         514                     Demons, Magic, Romance, Shoujo
# 1969  5140.0         917               Comedy, Ecchi, Harem, Romance, SciFi
# 3503  1857.0         958                               Action, Mecha, SciFi
# 136   2871.0        3103             Comedy, Magic, Romance, School, Shoujo
# 505   1012.0        3417   Action, Adventure, Fantasy, SciFi, Slice of Life
# 902   4776.0        6054             Comedy, Parody, Magic, Fantasy, Seinen
# 713   4937.0        4251               Ecchi, Comedy, Mecha, Romance, SciFi
# 714   3801.0        5689               Ecchi, Comedy, Mecha, Romance, SciFi
# 1859  4031.0        9415   Action, Adventure, Comedy, Ecchi, Parody, Seinen
# 1154  5237.0        5193  Parody, Adventure, Fantasy, Magic, Comedy, Rom...
# 2364  5738.0        4106  Action, Comedy, Parody, Super Power, Demons, S...
# 1223  4485.0        7581    Comedy, Fantasy, Magic, Romance, School, Shoujo
# 928   3578.0        1707  Adventure, Harem, Comedy, Supernatural, Magic,...
# 2978  3668.0        1116  Action, Comedy, Fantasy, Parody, SciFi, Supern...
# 189    740.0         187  Action, Adventure, Comedy, Historical, Demons,...
# 2068   294.0         692  Action, Adventure, Comedy, Historical, Demons,...
# 5074  4189.0        1709  Action, Adventure, Comedy, Historical, Demons,...
# 434   3875.0        9338                                 Adventure, Fantasy
# 3918  4095.0       11925                                 Adventure, Fantasy
# 135   1437.0         759  Action, Adventure, Fantasy, Magic, Romance, Su...
# 1381  5025.0        9851                         Adventure, Fantasy, Shoujo
# 4245   762.0         115  Action, Adventure, Fantasy, Magic, Shounen, Su...
# 5064  2948.0         958  Action, Adventure, Supernatural, Magic, Fantas...
# 3848  3140.0         262  Action, Adventure, Ecchi, Fantasy, Magic, Shou...
#
#                                                synopsis  \
# 3738  fter dying a laughable and pathetic death on h...
# 3996  hen Kazuma Satou died, he was given two choice...
# 4758  It is a normal day; everyone from deranged mil...
# 4912  Despite completing all the tasks given to them...
# 2577  kawa Ayumu was revived as a zombie by the cute...
# 515   Dreaming of a magical world every night, the y...
# 516   Usagi Tsukino and her friends have been living...
# 395   Usagi Tsukino is an average student and crybab...
# 1969  Kio is just another boring, nice guy with a bo...
# 3503  gelise Ikaruga Misurugi is the first princess ...
# 136   Fantasies and miracles never interested Ayu Ta...
# 505   The story is set in the 22nd century where spa...
# 902   The carefree Tsunami is next in line to rule o...
# 713   Five years ago, while battling an alien force ...
# 714   The history is placed right after the -cliffha...
# 1859  TV series from Monkey Punch with a 1-hour prem...
# 1154  "Look! In the sky...It's a bird...It's a plane...
# 2364  he Demon Patrol: a hotheaded demon prince; a s...
# 1223  Kanzaki Meirin, a junior high school student, ...
# 928   make of the Negima anime with its own original...
# 2978  fter years of fruitless war between the four r...
# 189   Based on the Shogakukan award-winning manga of...
# 2068  Thwarted again by Naraku, Inuyasha, Kagome Hig...
# 5074  Half-demon twins Towa and Setsuna were always ...
# 434   Pinon, the boy who flows within his body, the ...
# 3918  Sun Wukong, who was born from a magic stone, h...
# 135   During an excavation at the mysterious ruins i...
# 1381  atty girl named Mia is given a book, Thumbelin...
# 4245  The fierce battle between Meliodas, the captai...
# 5064                Fifth season of Nanatsu no Taizai .
# 3848  The Seven Deadly Sins, along with Elizabeth Li...
#
#                                                combined  \
# 3738  Adventure, Comedy, Fantasy, Magic, Parody, Sup...
# 3996  Adventure, Comedy, Parody, Supernatural, Magic...
# 4758  Comedy, Fantasy, Parody Emilia, SatouKazuma, N...
# 4912  Comedy, Parody, Fantasy Emilia, SatouKazuma, N...
# 2577  Action, Harem, Comedy, Supernatural, Magic, Ec...
# 515   Action, Adventure, Comedy, Fantasy, Shounen To...
# 516   Demons, Magic, Romance, Shoujo TsukinoUsagi, H...
# 395   Demons, Magic, Romance, Shoujo TsukinoUsagi, H...
# 1969  Comedy, Ecchi, Harem, Romance, SciFi Eris, Fut...
# 3503  Action, Mecha, SciFi IkarugaMisurugiAngelise, ...
# 136   Comedy, Magic, Romance, School, Shoujo SakuraN...
# 505   Action, Adventure, Fantasy, SciFi, Slice of Li...
# 902   Comedy, Parody, Magic, Fantasy, Seinen KawaiSa...
# 713   Ecchi, Comedy, Mecha, Romance, SciFi Saruwatar...
# 714   Ecchi, Comedy, Mecha, Romance, SciFi Saruwatar...
# 1859  Action, Adventure, Comedy, Ecchi, Parody, Sein...
# 1154  Parody, Adventure, Fantasy, Magic, Comedy, Rom...
# 2364  Action, Comedy, Parody, Super Power, Demons, S...
# 1223  Comedy, Fantasy, Magic, Romance, School, Shouj...
# 928   Adventure, Harem, Comedy, Supernatural, Magic,...
# 2978  Action, Comedy, Fantasy, Parody, SciFi, Supern...
# 189   Action, Adventure, Comedy, Historical, Demons,...
# 2068  Action, Adventure, Comedy, Historical, Demons,...
# 5074  Action, Adventure, Comedy, Historical, Demons,...
# 434   Adventure, Fantasy Pinon , the boy who flows w...
# 3918  Adventure, Fantasy SunWuKong  kong, who was bo...
# 135   Action, Adventure, Fantasy, Magic, Romance, Su...
# 1381  Adventure, Fantasy, Shoujo Mia atty girl named...
# 4245  Action, Adventure, Fantasy, Magic, Shounen, Su...
# 5064  Action, Adventure, Supernatural, Magic, Fantas...
# 3848  Action, Adventure, Ecchi, Fantasy, Magic, Shou...
#
#                                              Characters  \
# 3738  Megumin, SatouKazuma, Aqua, DustinessFordLalat...
# 3996  Megumin, SatouKazuma, Aqua, DustinessFordLalat...
# 4758  Emilia, SatouKazuma, NatsukiSubaru, Degurechaf...
# 4912  Emilia, SatouKazuma, NatsukiSubaru, Degurechaf...
# 2577  HellscytheEucliwood, AikawaAyumu, Seraphim, Yo...
# 515   ToramizuGinta, Dorothy, Alviss, Nanashi, Snow,...
# 516   TsukinoUsagi, HinoRei, KinoMakoto, AinoMinako,...
# 395   TsukinoUsagi, HinoRei, KinoMakoto, AinoMinako,...
# 1969  Eris, FutabaAoi, KinjouManami, KakazuKio, Chai...
# 3503  IkarugaMisurugiAngelise, SchlievogtHildegard, ...
# 136   SakuraNina, TateishiAyu, TsujiaiHiroki, KajiTe...
# 505   Luna, Kaoru, Howard, Menori, Bell, GyetAlduram...
# 902   KawaiSasami, AmanoMisao, MasakiTenchi, RyouOuk...
# 713   SaruwatariGoh, AoiAnna, AoiKiriko, FujimuraShi...
# 714   SaruwatariGoh, AoiAnna, AoiKiriko, FujimuraShi...
# 1859                             Dracula, JunJun, Omasa
# 1154  KokubuKarin, TonrariaanoIII, MizunoKouichi, Ma...
# 2364  Enma, Yukihime, FudouHarumi, Kapaeru, Chapeauj...
# 1223                          KanzakiMeirin, YuukiAsuka
# 928   McDowellEvangelineAthanasiaKatherine, Springfi...
# 2978  Neptune, Noire, Blanc, Vert, Pururut, Nepgear,...
# 189   Inuyasha, HigurashiKagome, Sango, Miroku, Ship...
# 2068  Inuyasha, HigurashiKagome, Sango, Miroku, Sess...
# 5074  Moroha, HigurashiTowa, Setsuna, Inuyasha, Sess...
# 434                                               Pinon
# 3918                                          SunWuKong
# 135   FlouriteFaiD, Sakura, Syaoran, Kurogane, Modok...
# 1381                                                Mia
# 4245  Ban, Meliodas, King, Hawk, Diane, Gowther, Lio...
# 5064  Ban, Meliodas, Escanor, King, Hawk, Diane, Gow...
# 3848  Ban, Meliodas, King, Hawk, Diane, Gowther, Lio...
#
#                                          char_name_list  \
# 3738  [Megumin, Satou, Kazuma, Aqua, Dustiness, Ford...
# 3996  [Megumin, Satou, Kazuma, Aqua, Dustiness, Ford...
# 4758  [Emilia, Satou, Kazuma, Natsuki, Subaru, Degur...
# 4912  [Emilia, Satou, Kazuma, Natsuki, Subaru, Degur...
# 2577  [Hellscythe, Eucliwood, Aikawa, Ayumu, Seraphi...
# 515   [Toramizu, Ginta, Dorothy, Alviss, Nanashi, Sn...
# 516   [Tsukino, Usagi, Hino, Rei, Kino, Makoto, Aino...
# 395   [Tsukino, Usagi, Hino, Rei, Kino, Makoto, Aino...
# 1969  [Eris, Futaba, Aoi, Kinjou, Manami, Kakazu, Ki...
# 3503  [Ikaruga, Misurugi, Angelise, Schlievogt, Hild...
# 136   [Sakura, Nina, Tateishi, Ayu, Tsujiai, Hiroki,...
# 505   [Luna, Kaoru, Howard, Menori, Bell, Gyet, Aldu...
# 902   [Kawai, Sasami, Amano, Misao, Masaki, Tenchi, ...
# 713   [Saruwatari, Goh, Aoi, Anna, Aoi, Kiriko, Fuji...
# 714   [Saruwatari, Goh, Aoi, Anna, Aoi, Kiriko, Fuji...
# 1859                         [Dracula, Jun, Jun, Omasa]
# 1154  [Kokubu, Karin, Tonrariaano, Mizuno, Kouichi, ...
# 2364  [Enma, Yukihime, Fudou, Harumi, Kapaeru, Chape...
# 1223                    [Kanzaki, Meirin, Yuuki, Asuka]
# 928   [Mc, Dowell, Evangeline, Athanasia, Katherine,...
# 2978  [Neptune, Noire, Blanc, Vert, Pururut, Nepgear...
# 189   [Inuyasha, Higurashi, Kagome, Sango, Miroku, S...
# 2068  [Inuyasha, Higurashi, Kagome, Sango, Miroku, S...
# 5074  [Moroha, Higurashi, Towa, Setsuna, Inuyasha, S...
# 434                                             [Pinon]
# 3918                                    [Sun, Wu, Kong]
# 135   [Flourite, Fai, Sakura, Syaoran, Kurogane, Mod...
# 1381                                              [Mia]
# 4245  [Ban, Meliodas, King, Hawk, Diane, Gowther, Li...
# 5064  [Ban, Meliodas, Escanor, King, Hawk, Diane, Go...
# 3848  [Ban, Meliodas, King, Hawk, Diane, Gowther, Li...
#
#                                          genre_and_char
# 3738  Adventure, Comedy, Fantasy, Magic, Parody, Sup...
# 3996  Adventure, Comedy, Parody, Supernatural, Magic...
# 4758  Comedy, Fantasy, Parody Emilia, SatouKazuma, N...
# 4912  Comedy, Parody, Fantasy Emilia, SatouKazuma, N...
# 2577  Action, Harem, Comedy, Supernatural, Magic, Ec...
# 515   Action, Adventure, Comedy, Fantasy, Shounen To...
# 516   Demons, Magic, Romance, Shoujo TsukinoUsagi, H...
# 395   Demons, Magic, Romance, Shoujo TsukinoUsagi, H...
# 1969  Comedy, Ecchi, Harem, Romance, SciFi Eris, Fut...
# 3503  Action, Mecha, SciFi IkarugaMisurugiAngelise, ...
# 136   Comedy, Magic, Romance, School, Shoujo SakuraN...
# 505   Action, Adventure, Fantasy, SciFi, Slice of Li...
# 902   Comedy, Parody, Magic, Fantasy, Seinen KawaiSa...
# 713   Ecchi, Comedy, Mecha, Romance, SciFi Saruwatar...
# 714   Ecchi, Comedy, Mecha, Romance, SciFi Saruwatar...
# 1859  Action, Adventure, Comedy, Ecchi, Parody, Sein...
# 1154  Parody, Adventure, Fantasy, Magic, Comedy, Rom...
# 2364  Action, Comedy, Parody, Super Power, Demons, S...
# 1223  Comedy, Fantasy, Magic, Romance, School, Shouj...
# 928   Adventure, Harem, Comedy, Supernatural, Magic,...
# 2978  Action, Comedy, Fantasy, Parody, SciFi, Supern...
# 189   Action, Adventure, Comedy, Historical, Demons,...
# 2068  Action, Adventure, Comedy, Historical, Demons,...
# 5074  Action, Adventure, Comedy, Historical, Demons,...
# 434                            Adventure, Fantasy Pinon
# 3918                       Adventure, Fantasy SunWuKong
# 135   Action, Adventure, Fantasy, Magic, Romance, Su...
# 1381                     Adventure, Fantasy, Shoujo Mia
# 4245  Action, Adventure, Fantasy, Magic, Shounen, Su...
# 5064  Action, Adventure, Supernatural, Magic, Fantas...
# 3848  Action, Adventure, Ecchi, Fantasy, Magic, Shou...

# %%
get_recommendation('bleach').iloc[-2, -2]
# Out:
# 'Action, Adventure, Comedy, Super Power, Supernatural, Shounen KurosakiIchigo, KuchikiRukia, AbaraiRenji "Hell" is the place where a person is sent to who committed violent crimes when they were alive. Shinigami are forbidden to go there. One day, prisoners revolt and make their escape to Karakura—the real world—where Ichigo and his friends live in. Ichigo and his friends are defeated one after the other by prisoners with overwhelming power. A mysterious man appears who comes to their rescue. With Kokutou leading the way, Ichigo, Rukia, Uryuu, and Renji marche into Hell to save the world. Note: Episode 299 of Bleach serves as a prologue to this movie. (Source: AniDB, edited)'

# %%
def get_link_by_text(soup, anime_id, text):
    a_tags = soup.find_all("a", text=text)
    links = list(filter(lambda x: str(anime_id) in x["href"], a_tags))
    return links[0]["href"]

# %%
anime_id = 1
data = requests.get(f"https://myanimelist.net/anime/{anime_id}")

anime_info = data.text
soup = BeautifulSoup(anime_info, "html.parser")

# %%
# Running once will only remove the first found <script> element,
# so it's unnecessary
# soup.script.decompose()

# %%
link_review = get_link_by_text(soup, anime_id, "Reviews")
link_recomendations = get_link_by_text(soup, anime_id, "Recommendations")
link_stats = get_link_by_text(soup, anime_id, "Stats")
link_staff = get_link_by_text(soup, anime_id, "Characters & Staff")
link_pictures = get_link_by_text(soup, anime_id, "Pictures")

# %%
link_review
# Out:
# 'https://myanimelist.net/anime/1/Cowboy_Bebop/reviews?p=24'

# %%
link = link_review
page = 23
actual_link = f"{link}?p={page}"
data = requests.get(actual_link)
soup = BeautifulSoup(data.text, "html.parser")
reviews = soup.find_all("a", text="Overall Rating")

# %%
list(filter(lambda x: str(anime_id) in x["href"], soup.find_all("a", text=text)))
# Out:
# [<a href="https://myanimelist.net/anime/1/Cowboy_Bebop/reviews">Reviews</a>]
